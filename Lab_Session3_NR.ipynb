# %%
pdr.get_data_yahoo('AAPL')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04   30.490000   30.642857   30.340000   30.572857   27.505054
# 2010-01-05   30.657143   30.798571   30.464285   30.625713   27.552608
# 2010-01-06   30.625713   30.747143   30.107143   30.138571   27.114347
# 2010-01-07   30.250000   30.285715   29.864286   30.082857   27.064222
# 2010-01-08   30.042856   30.285715   29.865715   30.282858   27.244156
# 2010-01-11   30.400000   30.428572   29.778572   30.015715   27.003820
# 2010-01-12   29.884285   29.967142   29.488571   29.674286   26.696650
# 2010-01-13   29.695715   30.132856   29.157143   30.092857   27.073221
# 2010-01-14   30.015715   30.065714   29.860001   29.918571   26.916422
# 2010-01-15   30.132856   30.228571   29.410000   29.418571   26.466595
# 2010-01-19   29.761429   30.741428   29.605715   30.719999   27.637430
# 2010-01-20   30.701429   30.792856   29.928572   30.247143   27.212029
# ...

# %%
import pandas_datareader as pdr

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# %%
import datetime
amzn = pdr.get_quote_yahoo('AAPL')
from pandas_datareader.data import Options

# %%
import pandas as pd
Data = pd.read_excel("Cleaned_Update_2017.xlsx",sheetname=0)

# %%
pdr.get_quote_yahoo('AAPL')
# Out:
#          PE change_pct    last  short_ratio    time
# AAPL  17.43     -0.65%  153.48          1.9  4:00pm

# %%
aapl = Options('ADP', 'yahoo')
data = aapl.get_all_data()
data.iloc[0:20, 0:20]
# Out:
#                                             Last    Bid    Ask   Chg  \
# Strike Expiry     Type Symbol
# 45.0   2018-01-19 put  ADP180119P00045000   0.05   0.00   0.10  0.00
#        2019-01-18 put  ADP190118P00045000   0.10   0.05   0.25  0.00
# 47.5   2018-01-19 put  ADP180119P00047500   0.05   0.00   0.10  0.00
#        2019-01-18 put  ADP190118P00047500   0.60   0.25   0.80  0.00
# 50.0   2018-01-19 put  ADP180119P00050000   0.05   0.00   0.15  0.00
#        2019-01-18 call ADP190118C00050000  55.00  59.00  63.80  0.00
#                   put  ADP190118P00050000   0.75   0.55   1.10  0.00
# 55.0   2018-01-19 put  ADP180119P00055000   0.05   0.00   0.10  0.00
#        2018-02-16 put  ADP180216P00055000   0.10   0.00   0.15  0.00
#        2019-01-18 put  ADP190118P00055000   0.25   0.10   0.45 -0.30
# 60.0   2018-01-19 put  ADP180119P00060000   0.05   0.00   0.15  0.00
#        2018-02-16 put  ADP180216P00060000   0.05   0.00   0.10 -0.15
# ...

# %%
ticker = Data.Entity
all_data = {}
for ticker in Data:
    start = pd.to_datetime(Data['YEAR'].astype(str), format='%Y')
    end = pd.to_datetime(Data['YEAR'].astype(str), format='%Y')
    all_data[ticker] = pdr.get_data_yahoo(ticker, start, end)

#prices = DataFrame({tic: data['Adj Close'] for tic, data in all_data.iteritems()})  
#returns = prices.pct_change()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-af77772ac344> in <module>()
#       4     start = pd.to_datetime(Data['YEAR'].astype(str), format='%Y')
#       5     end = pd.to_datetime(Data['YEAR'].astype(str), format='%Y')
# ----> 6     all_data[ticker] = pdr.get_data_yahoo(ticker, start, end)
#       7
#       8 #prices = DataFrame({tic: data['Adj Close'] for tic, data in all_data.iteritems()})
#
# /Users/nandinirajeswaran/Applications/anaconda/lib/python3.6/site-packages/pandas_datareader/data.py in get_data_yahoo(*args, **kwargs)
#      38
#      39 def get_data_yahoo(*args, **kwargs):
# ---> 40     return YahooDailyReader(*args, **kwargs).read()
#      41
#      42
#
# /Users/nandinirajeswaran/Applications/anaconda/lib/python3.6/site-packages/pandas_datareader/yahoo/daily.py in read(self)
#     113         """ read one data from specified URL """
# ...

# %%
def get_symbol(name):
   url = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(name)

   result = requests.get(url).json()

   for x in result['ResultSet']['Result']:
       if x['name'] == name:
           return x['symbol']
       
company = get_symbol("Microsoft Corporation")
print(company)
# Out:
# MSFT

# %%
import requests
import json
import urllib
def get_symbol(name):
    url = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(name)

    result =requests.get(url).json()
    #return result['ResultSet']['Query']

# %%
mylist = Data.Entity.T.tolist()

# %%
for  xyz in mylist:
    mylist_a = get_symbol(xyz)
    print(mylist_a)
# Out:
# AOL
# ADP
# Ameritrade Inc.
# Citigroup
# Cardsystems Solutions Inc.
# HPQ
# Countrywide Financial Corp
# KDDI
# T-Mobile, Deutsche Telecom
# AOL
# US Dept of Vet Affairs
# Texas Lottery
# City and Hackney Teaching Primary Care Trust
# GPS
# Compass Bank
# Monster.com
# Driving Standards Agency
# Driving Standards Agency,
# Hannaford Brothers Supermarket Chain
# AMTD
# FIS
# Dai Nippon Printing
# UK Revenue
# TK / TJ Maxx
# Service Personnel and Veterans Agency (UK)
# Stanford University
# UK Home Office
# AT
# SBUX
# RBS Worldpay
# Jefferson County
# UK Ministry of Defence
# University of Miami
# University of Utah Hospitals
# Norwegian Tax Authorities
# Data Processors International
# Chile Ministry Of Education
# GS Caltex
# BNY Mellon Shareowner Services
# Auction.co.kr
# US Dept of Defense
# US National Guard
# University of California Berkeley
# Affinity Health Plan, Inc.
# Virginia Prescription Monitoring Program
# Network Solutions
# Blue Cross Blue Shield of Tennessee
# ...

# %%
def get_symbol(name):
    url = "http://d.yimg.com/autoc.finance.yahoo.com/autoc?query={}&region=1&lang=en".format(name)

    result = requests.get(url).json()
    
    for x in result['ResultSet']['Result']:
        #if x['name'] == name :
            #if (x['exchDisp']=='NYSE'or x['exchDisp']=='NASDAQ'):
                #if x['typeDisp']=='Equity':
                    return x['symbol']
        
##company = get_symbol("twitter")
##print(company)
ticker=[]
cmp_name = Data.Entity
##for  xyz in cmp_name:
    ##ticker = get_symbol(xyz)
    ##print(ticker)
    
for  xyz in cmp_name:
    ticker.append(get_symbol(xyz))
    
    
print(ticker)
# Out:
# ['AOL-U.TI', 'ADP', None, 'CIT-U.TI', None, 'HPQ', None, 'KDDIY', None, 'AOL-U.TI', None, None, None, 'GPS', None, None, None, None, None, 'AMTD', 'FIS', 'DNPCF', None, None, None, None, None, 'AT', 'SBUX', None, None, None, '^UMIAMIFL', None, None, None, None, None, None, None, None, None, None, None, None, 'LYNS', None, None, 'IGRW', None, None, None, None, 'HTLF', None, 'AT', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'PPB.L', 'JPM-PB', None, None, None, None, None, None, None, None, None, None, None, None, None, None, 'CIT-U.TI', None, None, 'GB00B1Z54R10.L', None, None, None, 'SGAMY', None, None, None, None, None, None, None, 'NHS', None, None, None, '600488.SS', '200771.SZ', None, None, None, None, None, None, None, None, None, 'GPN', None, None, None, None, None, 'KTC.DU', None, None, 'ATVI', None, None, None, None, 'KCT.V', 'K55306BA2822.KS', None, None, None, None, None, None, 'CIT-U.TI', None, None, '2GF.F', 'NTDOY', 'TWTR', 'A
# ...

# %%
data_ticker = pd.DataFrame(ticker) 
data_ticker['Ticker_Symbol'] = pd.Series(ticker, index=data_ticker.index)

# %%
data_ticker
# Out:
#              0 Ticker_Symbol
# 0     AOL-U.TI      AOL-U.TI
# 1          ADP           ADP
# 2         None          None
# 3     CIT-U.TI      CIT-U.TI
# 4         None          None
# 5          HPQ           HPQ
# 6         None          None
# 7        KDDIY         KDDIY
# 8         None          None
# 9     AOL-U.TI      AOL-U.TI
# 10        None          None
# 11        None          None
# 12        None          None
# 13         GPS           GPS
# 14        None          None
# 15        None          None
# 16        None          None
# 17        None          None
# 18        None          None
# 19        AMTD          AMTD
# 20         FIS           FIS
# 21       DNPCF         DNPCF
# 22        None          None
# 23        None          None
# 24        None          None
# 25        None          None
# 26        None          None
# 27          AT            AT
# 28        SBUX          SBUX
# 29        None          None
# ..         ...           ...
# ...

# %%
Data['Ticker_symbol']= data_ticker['Ticker_Symbol']

# %%
Data.head()
# Out:
#                       Entity  YEAR  records lost  ORGANISATION  \
# 0                        AOL  2004      92000000           web
# 1  Automatic Data Processing  2005        125000     financial
# 3                  Citigroup  2005       3900000     financial
# 5            Hewlett Packard  2006        200000  tech, retail
# 7                       KDDI  2006       4000000      telecoms
#
#          METHOD OF LEAK                       DATA SENSITIVITY Ticker_symbol
# 0            inside job  Just email address/Online information      AOL-U.TI
# 1         poor security                   SSN/Personal details           ADP
# 3  lost / stolen device                Credit card information      CIT-U.TI
# 5  lost / stolen device                   SSN/Personal details           HPQ
# 7                hacked  Just email address/Online information         KDDIY

# %%
#Save the dataframe as a csv file
Data.to_csv('tickerSymbol.csv', index=False, encoding='utf-8')

# %%
#Drop empty columns(axis=1 for columns and axis=0 for rows; 
#how='all' to drop if all values are nan and how='any' to drop if any value is nan)
Data = Data.dropna(axis=0,how='any')

# %%
#Drop a row-1, inplace = True just fills within the same dataframe
data_ticker.drop(data_ticker.index[1:], inplace=True)

# %%
data_ticker.drop(data_ticker.columns[[0]], axis=1)
# Out:
#     Ticker_Symbol
# 0        AOL-U.TI
# 1             ADP
# 2            None
# 3        CIT-U.TI
# 4            None
# 5             HPQ
# 6            None
# 7           KDDIY
# 8            None
# 9        AOL-U.TI
# 10           None
# 11           None
# 12           None
# 13            GPS
# 14           None
# 15           None
# 16           None
# 17           None
# 18           None
# 19           AMTD
# 20            FIS
# 21          DNPCF
# 22           None
# 23           None
# 24           None
# 25           None
# 26           None
# 27             AT
# 28           SBUX
# 29           None
# ..            ...
# 223          None
# 224          None
# 225          None
# 226           DGX
# 227         ATGAX
# 228          None
# 229          None
# 230          None
# 231          None
# 232          None
# 233          None
# 234             T
# 235          None
# 236          None
# 237          None
# 238          None
# 239     035080.KQ
# 240          None
# ...

# %%
data_ticker = data_ticker.dropna(axis=0,how='any')

# %%
data_ticker
# Out:
#                    0    Ticker_Symbol
# 0           AOL-U.TI         AOL-U.TI
# 1                ADP              ADP
# 3           CIT-U.TI         CIT-U.TI
# 5                HPQ              HPQ
# 7              KDDIY            KDDIY
# 9           AOL-U.TI         AOL-U.TI
# 13               GPS              GPS
# 19              AMTD             AMTD
# 20               FIS              FIS
# 21             DNPCF            DNPCF
# 27                AT               AT
# 28              SBUX             SBUX
# 32         ^UMIAMIFL        ^UMIAMIFL
# 45              LYNS             LYNS
# 48              IGRW             IGRW
# 53              HTLF             HTLF
# 55                AT               AT
# 71             PPB.L            PPB.L
# 72            JPM-PB           JPM-PB
# 87          CIT-U.TI         CIT-U.TI
# 90    GB00B1Z54R10.L   GB00B1Z54R10.L
# 94             SGAMY            SGAMY
# 102              NHS              NHS
# 106        600488.SS        600488.SS
# ...

# %%
data_ticker = data_ticker.drop(data_ticker.columns[0], axis=1)

# %%
data_ticker
# Out:
#        Ticker_Symbol
# 0           AOL-U.TI
# 1                ADP
# 3           CIT-U.TI
# 5                HPQ
# 7              KDDIY
# 9           AOL-U.TI
# 13               GPS
# 19              AMTD
# 20               FIS
# 21             DNPCF
# 27                AT
# 28              SBUX
# 32         ^UMIAMIFL
# 45              LYNS
# 48              IGRW
# 53              HTLF
# 55                AT
# 71             PPB.L
# 72            JPM-PB
# 87          CIT-U.TI
# 90    GB00B1Z54R10.L
# 94             SGAMY
# 102              NHS
# 106        600488.SS
# 107        200771.SZ
# 117              GPN
# 123           KTC.DU
# 126             ATVI
# 131            KCT.V
# 132  K55306BA2822.KS
# ..               ...
# 162           UBI.PA
# 163             AABA
# 166             NDAQ
# 168            JAPSY
# 171                D
# 173             SPLS
# 175              UPS
# 176              CYH
# 181         AOL-U.TI
# 182               HD
# 183              TGT
# ...

# %%
import datetime as dt

all_data = {}
start = dt.datetime(2004,1,1)
end = dt.datetime(2017,6,6)


for index, row in data_ticker.iterrows():
    all_data = pdr.get_data_yahoo(data_ticker['Ticker_Symbol'], start, end)
    prices = pd.DataFrame({tic: data['Close'] for tic, data in all_data.iteritems()})
#prices = pd.DataFrame(prices)
#prices.columns = ['stock_price']
#data_ticker = data_ticker.merge(prices, how='left', left_on='Ticker_Symbol', right_index=True)
# Out:
# /Users/nandinirajeswaran/Applications/anaconda/lib/python3.6/site-packages/pandas_datareader/yahoo/daily.py:136: SymbolWarning: Failed to read symbol: 'AOL-U.TI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/nandinirajeswaran/Applications/anaconda/lib/python3.6/site-packages/pandas_datareader/yahoo/daily.py:136: SymbolWarning: Failed to read symbol: 'CIT-U.TI', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/nandinirajeswaran/Applications/anaconda/lib/python3.6/site-packages/pandas_datareader/yahoo/daily.py:136: SymbolWarning: Failed to read symbol: '^UMIAMIFL', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# /Users/nandinirajeswaran/Applications/anaconda/lib/python3.6/site-packages/pandas_datareader/yahoo/daily.py:136: SymbolWarning: Failed to read symbol: 'JPM-PB', replacing with NaN.
#   warnings.warn(msg.format(sym), SymbolWarning)
# ...

# %%
symbols_list = data_ticker.Ticker_Symbol
d = {}
for ticker in symbols_list:
    d[ticker] = pdr.DataReader(ticker, "yahoo", '2014-12-01')
pan = pd.Panel(d)

print(pan)
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-120-d4b21763e1d4> in <module>()
#       4 d = {}
#       5 for ticker in symbols_list:
# ----> 6     d[ticker] = pdr.DataReader(ticker, "yahoo", '2014-12-01')
#       7 pan = pd.Panel(d)
#       8
#
# /Users/nandinirajeswaran/Applications/anaconda/lib/python3.6/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, access_key)
#     119                                 adjust_price=False, chunksize=25,
#     120                                 retry_count=retry_count, pause=pause,
# --> 121                                 session=session).read()
#     122
#     123     elif data_source == "yahoo-actions":
#
# /Users/nandinirajeswaran/Applications/anaconda/lib/python3.6/site-packages/pandas_datareader/yahoo/daily.py in read(self)
# ...

# %%
start = datetime.datetime(2004,1,1)
end = datetime.datetime(2017,6,6)

# bond_prices = web.DataReader("AGG", 'yahoo', start, end)
bond_prices = pdr.get_data_yahoo("AABA", start, end)

# %%
bond_prices.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2004-01-02  22.750000  22.915001  22.559999  22.700001  22.700001  16480000
# 2004-01-05  22.879999  23.555000  22.674999  23.450001  23.450001  23107800
# 2004-01-06  23.219999  23.725000  23.174999  23.620001  23.620001  20527800
# 2004-01-07  23.450001  23.879999  23.424999  23.834999  23.834999  19229000
# 2004-01-08  24.000000  24.485001  23.934999  24.290001  24.290001  25469200

# %%
import datetime
start = datetime.datetime(2004,1,1)
end = datetime.datetime(2017,6,6)
data_source = 'yahoo'
panel_data = pdr.DataReader(ticker, data_source, start, end)

# %%
panel_data
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2009-02-13  19.200001  19.200001  19.200001  19.200001  17.603231       0
# 2009-02-17  19.200001  19.200001  19.200001  19.200001  17.603231       0
# 2009-02-18  19.200001  19.200001  19.200001  19.200001  17.603231       0
# 2009-02-19  19.200001  19.200001  19.200001  19.200001  17.603231       0
# 2009-02-20  19.200001  19.200001  19.200001  19.200001  17.603231       0
# 2009-02-23  19.200001  19.200001  19.200001  19.200001  17.603231       0
# 2009-02-24  16.299999  16.299999  16.299999  16.299999  14.944408   18400
# 2009-02-25  16.299999  16.299999  16.299999  16.299999  14.944408       0
# 2009-02-26  16.400000  16.400000  16.400000  16.400000  15.036094    2000
# 2009-02-27  16.400000  16.400000  16.400000  16.400000  15.036094       0
# 2009-03-02  16.400000  16.400000  16.400000  16.400000  15.036094       0
# 2009-03-03  15.800000  15.800000  15.800000  15.800000  14.485993     500
# ...

# %%
prices = pd.DataFrame({tic: data['Close'] for tic, data in all_data.iteritems()})
